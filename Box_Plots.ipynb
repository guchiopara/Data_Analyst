# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['HTMLPhish', 'Decision Tree', 'AdaBoost', 'SVM', 'Logistics regression']

data_1 = [0.8688, 0.8729, 0.8045,0.8718]
#print(data_1)
data_2 = [0.3777, 0.3978, 0.3991, 0.3767]
data_3 = [0.4777, 0.4978, 0.6991, 0.4767]
data_4 = [0.2777, 0.2978, 0.2991, 0.2767]
data_5 = [0.6777, 0.5978, 0.6991, 0.6767]
score_sets = [data_1, data_2, data_3, data_4, data_5]


import matplotlib.pyplot 

#matplotlib.pyplot.plot(sizes, marker='o')
#matplotlib.pyplot.savefig('train_size1.pdf', transparent=False)
#matplotlib.pyplot.show()
# plot distributions of test accuracy for train size
matplotlib.pyplot.boxplot(score_sets, labels=sizes)
matplotlib.pyplot.savefig('box_plot_fpr_htmlphish.pdf', transparent=False)
matplotlib.pyplot.show()


#data_1 = [0.9777, 0.9978, 0.9991, 0.9767, 0.9993, 0.9998]
#print(data_1)
#data_2 = [0.9777, 0.9978, 0.9991, 0.9767, 0.9993, 0.9998]
#data_3 = [0.9777, 0.9978, 0.9991, 0.9767, 0.9993, 0.9998]
#data_4 = [0.9777, 0.9978, 0.9991, 0.9767, 0.9993, 0.9998]
#data = [data_1, data_2, data_3, data_4]
 
#fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
##ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
#bp = ax.boxplot(data)
 
# show plot
#plt.show()

# %%
#FPR

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['HTMLPhish', 'Decision Tree', 'AdaBoost', 'SVM', 'Logistics regression']

data_1 = [0.8688, 0.8729, 0.8045,0.8718]
#print(data_1)
data_2 = [0.3777, 0.3978, 0.3991, 0.3767]
data_3 = [0.4777, 0.4978, 0.6991, 0.4767]
data_4 = [0.2777, 0.2978, 0.2991, 0.2767]
data_5 = [0.6777, 0.5978, 0.6991, 0.6767]
score_sets = [data_1, data_2, data_3, data_4, data_5]

# fake up some data
spread= rand(50) * 100
center = ones(25) * 50
flier_high = rand(10) * 100 + 100
flier_low = rand(10) * -100
data =concatenate((spread, center, flier_high, flier_low), 0)

# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('FPR', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_fpr_htmlphish.pdf', transparent=False)

plt.show()

# %%
#FNR

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['HTMLPhish', 'Decision Tree', 'AdaBoost', 'SVM', 'Logistics regression']

data_1 = [0.7685, 0.7729, 0.7045,0.7718]
#print(data_1)
data_2 = [0.9682, 0.9678, 0.9691, 0.9767]
data_3 = [0.7777, 0.7978, 0.7991, 0.7767]
data_4 = [0.9674, 0.9578, 0.9791, 0.9667]
data_5 = [0.9572, 0.9578, 0.9591, 0.9367]
score_sets = [data_1, data_2, data_3, data_4, data_5]

# fake up some data
spread= rand(50) * 100
center = ones(25) * 50
flier_high = rand(10) * 100 + 100
flier_low = rand(10) * -100
data =concatenate((spread, center, flier_high, flier_low), 0)

# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('FNR', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_fnr_htmlphish.pdf', transparent=False)

plt.show()

# %%
#F1_Score

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['HTMLPhish', 'Decision Tree', 'AdaBoost', 'SVM', 'Logistics regression']

data_1 = [0.7985, 0.7929, 0.7945,0.7918]
#print(data_1)
data_2 = [0.5553, 0.5678, 0.5691, 0.5767]
data_3 = [0.5376, 0.5378, 0.5391, 0.5457]
data_4 = [0.4013, 0.4578, 0.4791, 0.4867]
data_5 = [0.7572, 0.7578, 0.7591, 0.7367]
score_sets = [data_1, data_2, data_3, data_4, data_5]

# fake up some data
spread= rand(50) * 100
center = ones(25) * 50
flier_high = rand(10) * 100 + 100
flier_low = rand(10) * -100
data =concatenate((spread, center, flier_high, flier_low), 0)

# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('F1_Score', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_f1_score_htmlphish.pdf', transparent=False)

plt.show()

# %%
#AUC_Score

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['HTMLPhish', 'Decision Tree', 'AdaBoost', 'SVM', 'Logistics regression']

data_1 = [0.924, 0.929, 0.925,0.918]
#print(data_1)
data_2 = [0.694, 0.667, 0.669, 0.676]
data_3 = [0.700, 0.707, 0.709, 0.705]
data_4 = [0.626, 0.657, 0.621, 0.627]
data_5 = [0.808, 0.857, 0.801, 0.807]
score_sets = [data_1, data_2, data_3, data_4, data_5]

# fake up some data
spread= rand(50) * 100
center = ones(25) * 50
flier_high = rand(10) * 100 + 100
flier_low = rand(10) * -100
data =concatenate((spread, center, flier_high, flier_low), 0)

# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('AUC', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_AUC_score_htmlphish.pdf', transparent=False)

plt.show()

# %%
#Recall HTMLPhish_Variant

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['Proposed_HTMLPhish', 'HTMLPhish-Character', 'HTMLPhish-Word']

data_1 = [0.864, 0.872, 0.804,0.871]
#print(data_1)
data_2 = [0.632, 0.678, 0.631, 0.671]
data_3 = [0.831, 0.837, 0.832, 0.836]
#data_4 = [0.9674, 0.9578, 0.9791, 0.9667]
#data_5 = [0.9572, 0.9578, 0.9591, 0.9367]
score_sets = [data_1, data_2, data_3]



# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('Recall', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_recall_htmlphish.pdf', transparent=False)

plt.show()

# %%
# Import Libraries

import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# Define Data

dates = ['SrcPageRank', 'SrcHubs', 'SrcAuth', 'SrcDegCnt', 
         'SrcBetCnt', 'SrcDeg', 'TgtPageRank', 'TgtHubs', 
         'TgtAuth', 'TgtDegCnt', 'TgtBetCnt', 'TgtDeg']

y =  [0.8851331139694885, 0.8851331139694885, 0.8842357164223751,0.884833981453784,
          0.8872270415794197, 0.8845348489380795, 0.8863296440323063, 0.8836374513909662, 
          0.8836374513909662, 0.881543523781035, 0.8839365839066706, 0.8830391863595572]
x = [0.6967271014834, 0.6939493433395872, 0.6984877126654064, 0.6953455571227081,
         0.6961624222509095, 0.6947022201339128,  0.6886693782684485, 0.6950588235294117,
          0.6984277101312212, 0.6946375957572185, 0.6880894166957736, 0.6972130373169579]
# Plotting
#precision 0.5741885625965997
#recall 0.8890218366736464
#plt.plot_date(dates, y, '-')
plt.plot_date(dates, x, '-')
plt.xlabel('Features')
plt.ylabel('F1_Score')

# Avoid overlapping

plt.gcf().autofmt_xdate(bottom=0.15)

# Visualize
plt.savefig('f1score.png', bbox_inches="tight")
plt.show()

# %%
#AUC HTMLPhish_Variant

import matplotlib.pyplot as plt
from pylab import *
import numpy as np
 

#sizes = [20000, 30000, 35000, 40000, 50000]

sizes = ['SrcPageRank', 'SrcHubs', 'SrcAuth', 'SrcDegCnt', 
         'SrcBetCnt', 'SrcDeg', 'TgtPageRank', 'TgtHubs', 
         'TgtAuth', 'TgtDegCnt', 'TgtBetCnt', 'TgtDeg']

data_1 = [0.8851331139694885, 0.8851331139694885, 0.8842357164223751,0.884833981453784,
          0.8872270415794197, 0.8845348489380795, 0.8863296440323063, 0.8836374513909662, 
          0.8836374513909662, 0.881543523781035, 0.8839365839066706, 0.8830391863595572]
#print(data_1)
data_2 = [0.6967271014834, 0.6939493433395872, 0.6984877126654064, 0.6953455571227081,
         0.6961624222509095, 0.6947022201339128,  0.6886693782684485, 0.6950588235294117,
          0.6984277101312212, 0.6946375957572185, 0.6880894166957736, 0.6972130373169579, 0.6971334586466166]
#data_3 = [0.921, 0.927, 0.922, 0.926]
#data_4 = [0.9674, 0.9578, 0.9791, 0.9667]
#data_5 = [0.9572, 0.9578, 0.9591, 0.9367]
score_sets = [data_1, data_2]



# figure related code
fig = plt.figure()
#fig.suptitle('Comparison of FPR of Algorithms', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(score_sets, labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('AUC_Score', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_AUC_htmlphish.pdf', transparent=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d66c24d3bd91> in <module>()
#      29
#      30 ax = fig.add_subplot(111)
# ---> 31 ax.boxplot(score_sets, labels=sizes)
#      32
#      33
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     294                 f"for the old name will be dropped %(removal)s.")
#     295             kwargs[new] = kwargs.pop(old)
# --> 296         return func(*args, **kwargs)
#     297
#     298     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

sizes = ['Proposed_HTMLPhish', 'HTMLPhish-Character', 'HTMLPhish-Word']

plt.plot(y1,labels=sizes)
plt.plot(y2,labels=sizes)


ax.set_xlabel('Algorithms', fontsize=12, fontweight='bold')
ax.set_ylabel('AUC_Score', fontsize=12, fontweight='bold')
matplotlib.pyplot.savefig('box_plot_AUC_htmlphish.pdf', transparent=False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3dc7840d0e05> in <module>()
#       7 sizes = ['Proposed_HTMLPhish', 'HTMLPhish-Character', 'HTMLPhish-Word']
#       8
# ----> 9 plt.plot(y1,labels=sizes)
#      10 plt.plot(y2,labels=sizes)
#      11
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...

# %%
x_data = df['Product Type']
y_data = df['Total Amount']

def lineplot(x_data, y_data, x_label="Product Type", y_label="Total Amount", title="Sales"):
    __, ax = plt.subplots()

    ax.plot(x_data, y_data, lw=3, color ='#539caf', alpha =1)

    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

lineplot(x_data, y_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Saw kwargs ['ls', 'linestyle'] which are all aliases for 'linestyle'.  Kept value from 'linestyle'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Saw kwargs ['ls', 'linestyle'] which are all aliases for 'linestyle'.  Kept value from 'linestyle'.  Passing multiple aliases for the same property will raise a TypeError in 3.3.
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7519199b6b77> in <module>()
#       9 d1, = plt.plot(xdata, ydata1, "sb", markersize = 5, ls = "solid", label = 'name1', linestyle = 'dashed')
# ...
